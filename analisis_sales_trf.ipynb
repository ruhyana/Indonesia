# %% [markdown]
# <a href="https://colab.research.google.com/github/ruhyana/Indonesia/blob/master/analisis_sales_trf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **DATA DICTIONARY**
#
# | Variable      | Description                                                                                                 |
# | ------------- | ----------------------------------------------------------------------------------------------------------- |
# | id_product           | A notation for a house                                                                                      |
# | date          | Date house was sold                                                                                         |
# | price         | Price is prediction target                                                                                  |
# | bedrooms      | Number of bedrooms                                                                                          |
# | bathrooms     | Number of bathrooms                                                                                         |
# | sqft_living   | Square footage of the home                                                                                  |
# | sqft_lot      | Square footage of the lot                                                                                   |
# | floors        | Total floors (levels) in house                                                                              |
# | waterfront    | House which has a view to a waterfront                                                                      |
# | view          | Has been viewed                                                                                             |
# | condition     | How good the condition is overall                                                                           |
# | grade         | overall grade given to the housing unit, based on King County grading system                                |
# | sqft_above    | Square footage of house apart from basement                                                                 |
# | sqft_basement | Square footage of the basement                                                                              |
# | yr_built      | Built Year                                                                                                  |
# | yr_renovated  | Year when house was renovated                                                                               |
# | zipcode       | Zip code                                                                                                    |
# | lat           | Latitude coordinate                                                                                         |
# | long          | Longitude coordinate                                                                                        |
# | sqft_living15 | Living room area in 2015(implies-- some renovations) This might or might not have affected the lotsize area |
# | sqft_lot15    | LotSize area in 2015(implies-- some renovations)                                                            |

# %% [markdown]
# # 1.ANALISIS SALES TRF

# %% [markdown]
# ## 1 Analisis data sales

# %% [markdown]
# ###**Import package & library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Read dataset**

# %%
data_sales = pd.read_csv('/content/drive/MyDrive/TRF DATA/sales_181920_ok.csv')
data_product = pd.read_csv('/content/drive/MyDrive/TRF DATA/data_product.csv')

# %%
data_medreps =pd.read_csv('/content/drive/MyDrive/TRF DATA/master_mr.csv')

# %%
data_medreps.head()

# %%
data_medreps.info()

# %%
data_product.head()
# Out:
#   MaterialCode              MaterialDesc      Kemasan  Satuan StatusProduct  \
# 0    210-08-00           ALIF 500 KAPLET  Folding Box     100         Aktif
# 1    013-29-01  BELVAS 10/TAB 3X10'S FBX  Folding Box      30         Aktif
# 2    013-29-02   BELVAS 5/TAB 3X10'S FBX  Folding Box      30         Aktif
# 3    012-45-00         BEXCE/KAP 10X10'S  Folding Box     100         Aktif
# 4    012-46-05     BEXCE PLUS DROP 15 ML       Bottle       1         Aktif
#
#        SubCategory Category  IdCategory  \
# 0  ETHICAL BRANDED       EP           0
# 1  ETHICAL BRANDED       EP           0
# 2  ETHICAL BRANDED       EP           0
# 3  ETHICAL BRANDED       EP           0
# 4  ETHICAL BRANDED       EP           0
#
#                                            Komposisi           LastUpdate  \
# 0                   Naproxen sodium ~ Naproxen 500mg  0000-00-00 00:00:00
# 1                           Amlodipin besylate 10 mg  0000-00-00 00:00:00
# ...

# %% [markdown]
# # New Section

# %%
data_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MaterialCode   283 non-null    object
#  1   MaterialDesc   283 non-null    object
#  2   Kemasan        165 non-null    object
#  3   Satuan         283 non-null    int64
#  4   StatusProduct  154 non-null    object
#  5   SubCategory    283 non-null    object
#  6   Category       283 non-null    object
#  7   IdCategory     283 non-null    int64
#  8   Komposisi      151 non-null    object
#  9   LastUpdate     283 non-null    object
#  10  Remarks        283 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 24.4+ KB

# %%
data_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295052 entries, 0 to 295051
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   SalesOrderNo      295052 non-null  object
#  1   OrderType         295052 non-null  object
#  2   OrderCN           6750 non-null    object
#  3   CompanyCode       295052 non-null  int64
#  4   TanggalSO         295052 non-null  object
#  5   Program           295052 non-null  object
#  6   PrincipalCode     295052 non-null  object
#  7   ProductHirarki    295052 non-null  object
#  8   SalesOfficePlant  295052 non-null  int64
#  9   SubCustomerCode   295052 non-null  object
#  10  NoCustVerSAP      295052 non-null  int64
#  11  CustomerName      295052 non-null  object
#  12  CustomerAddress   295052 non-null  object
#  13  MaterialCode      295052 non-null  object
#  14  MaterialDesc      295052 non-null  object
#  15  TanggalDO         295052 non-null  object
# ...

# %%
data_sales.shape #Melihat jumlah record dan jumlah kolom
# Out:
# (295052, 24)

# %%
data_medreps.shape
# Out:
# (125, 19)

# %%
data_medreps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NRP               125 non-null    object
#  1   PinCode           125 non-null    object
#  2   FFName            125 non-null    object
#  3   SalesOfficePlant  125 non-null    int64
#  4   StatusFF          125 non-null    object
#  5   Title             125 non-null    object
#  6   AwalKerja         125 non-null    object
#  7   AkhirKerja        125 non-null    object
#  8   IdRegion          1 non-null      object
#  9   Divisi            1 non-null      object
#  10  NoTelpon          125 non-null    object
#  11  IdHandphone       1 non-null      object
#  12  NPWP              107 non-null    object
#  13  AlamatNPWP        108 non-null    object
#  14  NoRekBCA          108 non-null    object
#  15  Email             2 non-null      object
# ...

# %%
data_sales.tail()
# Out:
#        SalesOrderNo OrderType OrderCN  CompanyCode   TanggalSO Program  \
# 295047   CS0428582       ZB2A       M         8020  2018-12-27      DO
# 295048   CS4100048       ZCO9       O         8020  2018-12-20      CN
# 295049   CS4100048       ZCO9       O         8020  2018-12-20      CN
# 295050   CS4100048       ZCO9       O         8020  2018-12-20      CN
# 295051   CS4100049       ZCO9       O         8020  2018-12-20      CN
#
#        PrincipalCode      ProductHirarki  SalesOfficePlant SubCustomerCode  \
# 295047           TRF  TRFEPAEPA                        282            008A
# 295048           TRF  TRFEPAEPA                        282            008A
# 295049           TRF  TRFEPAEPA                        282            008A
# 295050           TRF  TRFEPAEPA                        282            008A
# 295051           TRF  TRFEPAEPA                        282            008A
#
#         ...                              MaterialDesc   TanggalDO     NomorDO  \
# ...

# %%
data_sales.describe()
# Out:
#        CompanyCode  SalesOfficePlant  NoCustVerSAP    GrossSales  \
# count     295052.0     295052.000000  2.950520e+05  2.950520e+05
# mean        8020.0        231.343756  4.001317e+08  2.186592e+06
# std            0.0         26.445091  9.626625e+05  1.194615e+07
# min         8020.0        202.000000  1.000007e+08 -5.130000e+08
# 25%         8020.0        205.000000  4.000439e+08  1.146400e+05
# 50%         8020.0        223.000000  4.000928e+08  3.493400e+05
# 75%         8020.0        252.000000  4.002459e+08  1.181550e+06
# max         8020.0        292.000000  4.003202e+08  1.050000e+09
#
#                QtyDO     DiscountA     DiscountB  DiscountC     DiscountE  \
# count  295052.000000  2.950520e+05  2.950520e+05   295052.0  2.950520e+05
# mean       47.490597  8.626928e+03  8.615409e+05        0.0  2.467678e+01
# std       460.950603  2.653588e+05  8.431045e+06        0.0  5.073733e+03
# min    -17462.000000 -4.356660e+06 -4.409708e+08        0.0 -6.453400e+04
# ...

# %%
data_sales.dtypes
# Out:
# SalesOrderNo         object
# OrderType            object
# OrderCN              object
# CompanyCode           int64
# TanggalSO            object
# Program              object
# PrincipalCode        object
# ProductHirarki       object
# SalesOfficePlant      int64
# SubCustomerCode      object
# NoCustVerSAP          int64
# CustomerName         object
# CustomerAddress      object
# MaterialCode         object
# MaterialDesc         object
# TanggalDO            object
# NomorDO              object
# GrossSales            int64
# QtyDO               float64
# DiscountA             int64
# DiscountB             int64
# DiscountC             int64
# DiscountE             int64
# DiscountF             int64
# dtype: object

# %%
data_product.info()

# %%
data_product.head()

# %%
data_medreps.tail()
# Out:
#                NRP      PinCode              FFName  SalesOfficePlant  \
# 120     2014070048   2014070048    DONNY APRILIANTO               264
# 121    K2021060011  K2021060011              HENDRA               268
# 122    K2019060036  K2019060036     PANDU WICAKSONO               290
# 123     2013090055   2013090055              SUKRON               220
# 124  2011010045GTO           \N  VACANT - GORONTALO               275
#
#      StatusFF Title   AwalKerja  AkhirKerja IdRegion Divisi      NoTelpon  \
# 120  Berhenti    MR  2014-07-01  2020-06-30      NaN    NaN             0
# 121     Aktif    MR  2021-07-01  9999-12-31      NaN    NaN  085246667757
# 122  Berhenti    MR  2019-06-01  2019-10-30      NaN    NaN             0
# 123  Berhenti    MR  2013-06-01  2019-10-30      NaN    NaN             0
# 124    BackUp   SPV          \N          \N       \N     \N            \N
#
#     IdHandphone NPWP AlamatNPWP NoRekBCA Email Alamat           LastUpdate  \
# ...
